# %%
# jupyter nbconvert --to notebook --execute Senti+GUI.ipynb
# # Enter your answer for Question 1: I like to be a part of an organisation where my opinions affect the direction in which it moves
# # Enter your answer for Question 2: Extremely Hands On
# # Enter your answer for Question 3: the decentrality and that everyone is accountable and transparent
# # Enter your answer for Question 4: I haven't thought about it
# # Enter your answer for Question 5: It should be the main driving force 
# # Enter your answer for Question 6: Long term benefits for the win
# # Enter your answer for Question 7: Anything that revolves around incorporation of new technology and monetary changes
# # Enter your answer for Question 8: I am not experienced with that
# # Enter your answer for Question 9: Visible changes and accountable change makers
# # Enter your answer for Question 10: technology is key to the progress and sustainence of the DAO
# # Enter your answer for Question 11: I do not have the ability to comment on that
# # Enter your answer for Question 12: Not a clue
# # Enter your answer for Question 13: We need to transition to a completely on-chain process
# # Enter your answer for Question 14: Participation tokens for a while which can be redeemed for benefits
# # Enter your answer for Question 15: Innovative and creative things

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

class ProposalVotingApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Sign-Up QnA + Gauging")

        # Initialize variables to store user responses
        self.user_responses = {}
        self.df_responses = None  # Initialize DataFrame attribute

        # Create widgets
        self.create_question_widgets()
        self.create_proposal_widgets()
        self.create_buttons()

    def create_question_widgets(self):
        questions = [
            "What motivates you to participate in a DAO?",
            "How would you describe your preferred level of involvement in DAO decision-making?",
            "What factors influence your trust in a DAO's decision-making process?",
            "Describe your approach to assessing the potential impact of a DAO proposal on the community.",
            "In your view, what role should community sentiment play in DAO decision-making?",
            "How do you prioritize between short-term gains and long-term sustainability when evaluating DAO proposals?",
            "Describe the type of proposals you believe should require a higher quorum for approval.",
            "How would you contribute to resolving conflicts within the DAO community?",
            "Explain your criteria for supporting a proposal aimed at modifying the DAO's governance structure.",
            "What role do you see technology playing in enhancing DAO governance?"
        ]

        for i, question in enumerate(questions):
            question_label = ttk.Label(self.root, text=question)
            question_label.grid(row=i, column=0, padx=5, pady=5, sticky="w")

            answer_entry = ttk.Entry(self.root, width=30)
            answer_entry.grid(row=i, column=1, padx=5, pady=5)
            self.user_responses[f'Q{i + 1}'] = answer_entry

    def create_proposal_widgets(self):
        proposals = [
            "Enhance community engagement through monthly town hall meetings.",
            "Implement a decentralized grants program to fund community-driven initiatives.",
            "Integrate NFTs to enhance DAO membership and governance token representation.",
            "Collaborate with external projects for cross-platform incentives.",
            "Implement policies for diverse representation in governance roles.",
            "Introduce governance badges or NFTs as recognition for active participants.",
            "Create educational initiatives to promote inclusivity within the community.",
            "Implement a clear and accessible dispute resolution process.",
            "Facilitate open and constructive dialogue between conflicting parties.",
            "Establish mentorship programs to support underrepresented individuals."
        ]

        for i, proposal in enumerate(proposals):
            proposal_label = ttk.Label(self.root, text=proposal)
            proposal_label.grid(row=i, column=2, padx=5, pady=5, sticky="w")

            vote_entry = ttk.Entry(self.root, width=5)
            vote_entry.grid(row=i, column=3, padx=5, pady=5)
            self.user_responses[f'Vote_Proposal_{i + 1}'] = vote_entry

    def create_buttons(self):
        submit_button = ttk.Button(self.root, text="Submit", command=self.submit_responses)
        submit_button.grid(row=len(self.user_responses), column=0, columnspan=2, pady=10)

        exit_button = ttk.Button(self.root, text="Exit", command=self.root.destroy)
        exit_button.grid(row=len(self.user_responses), column=2, columnspan=2, pady=10)

    def submit_responses(self):
        # Create a DataFrame from the user responses
        self.df_responses = pd.DataFrame.from_dict({key: [value.get()] for key, value in self.user_responses.items()})
        
        # Display the DataFrame
#         print(self.df_responses)

if __name__ == "__main__":
    root = tk.Tk()
    app = ProposalVotingApp(root)
    root.mainloop()

# Access the DataFrame later using app.df_responses

# %%
import pandas as pd

# List of questions
questions = [
    "What motivates you to participate in a DAO?",
    "How would you describe your preferred level of involvement in DAO decision-making?",
    "What factors influence your trust in a DAO's decision-making process?",
    "Describe your approach to assessing the potential impact of a DAO proposal on the community.",
    "In your view, what role should community sentiment play in DAO decision-making?",
    "How do you prioritize between short-term gains and long-term sustainability when evaluating DAO proposals?",
    "Describe the type of proposals you believe should require a higher quorum for approval.",
    "How would you contribute to resolving conflicts within the DAO community?",
    "Explain your criteria for supporting a proposal aimed at modifying the DAO's governance structure.",
    "What role do you see technology playing in enhancing DAO governance?"
]

# Create a DataFrame
df1 = pd.DataFrame(questions, columns=['Questions'])

# Assume df_responses is the DataFrame containing responses from the GUI
df_responses = app.df_responses.T

# Extract the first row of the DataFrame (assuming one user's responses)
user_responses = df_responses[:10].iloc[:, 0].tolist()

# Insert the user_responses as a new column in df1
df1['User_Responses'] = user_responses

# Display the updated DataFrame
df1
# Out:
#                                            Questions User_Responses
# 0        What motivates you to participate in a DAO?           qqqq
# 1  How would you describe your preferred level of...              q
# 2  What factors influence your trust in a DAO's d...              q
# 3  Describe your approach to assessing the potent...              q
# 4  In your view, what role should community senti...              q
# 5  How do you prioritize between short-term gains...              q
# 6  Describe the type of proposals you believe sho...              q
# 7  How would you contribute to resolving conflict...              e
# 8  Explain your criteria for supporting a proposa...             tt
# 9  What role do you see technology playing in enh...             yg

# %%
# !pip install vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Rename the columns to match the desired format
df1.columns = ['questions', 'User_1']

# Create a VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to get sentiment scores for a given text
def get_sentiment_scores(text):
    return analyzer.polarity_scores(text)

# Apply VADER sentiment analysis to each column (user responses and questions) in the DataFrame
for column in ['questions','User_1']:
    df1[f'{column}_sentiment'] = df1[column].apply(get_sentiment_scores)

# Display the resulting DataFrame with sentiment scores
result_df=df1
result_df
# Out:
#                                            questions User_1  \
# 0        What motivates you to participate in a DAO?   qqqq
# 1  How would you describe your preferred level of...      q
# 2  What factors influence your trust in a DAO's d...      q
# 3  Describe your approach to assessing the potent...      q
# 4  In your view, what role should community senti...      q
# 5  How do you prioritize between short-term gains...      q
# 6  Describe the type of proposals you believe sho...      q
# 7  How would you contribute to resolving conflict...      e
# 8  Explain your criteria for supporting a proposa...     tt
# 9  What role do you see technology playing in enh...     yg
#
#                                  questions_sentiment  \
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'comp...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...

# %%
# Assuming 'result_df' is your DataFrame
column_types = result_df.dtypes


# Display the schema
print(column_types)
# Out:
# questions              object
# User_1                 object
# questions_sentiment    object
# User_1_sentiment       object
# dtype: object

# %%
# Create a copy of the DataFrame with only the VADER sentiment scores
vader_df = result_df.filter(like='_sentiment').copy()

# Display the DataFrame with only the VADER sentiment scores
(vader_df)
# Out:
#                                  questions_sentiment  \
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'comp...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'comp...
# 5  {'neg': 0.0, 'neu': 0.844, 'pos': 0.156, 'comp...
# 6  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...
# 7  {'neg': 0.183, 'neu': 0.634, 'pos': 0.183, 'co...
# 8  {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'comp...
# 9  {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'comp...
#
#                                     User_1_sentiment
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...

# %%
import pandas as pd

# Number of believable proposals
num_proposals = 10

# Generate believable proposals
proposals = {
    'proposal': [
        "Enhance community engagement through monthly town hall meetings.",
        "Implement a decentralized grants program to fund community-driven initiatives.",
        "Integrate NFTs to enhance DAO membership and governance token representation.",
        "Collaborate with external projects for cross-platform incentives.",
        "Implement policies for diverse representation in governance roles.",
        "Introduce governance badges or NFTs as recognition for active participants.",
        "Create educational initiatives to promote inclusivity within the community.",
        "Implement a clear and accessible dispute resolution process.",
        "Facilitate open and constructive dialogue between conflicting parties.",
        "Establish mentorship programs to support underrepresented individuals."
    ]
}

# Create a DataFrame for proposals
df_proposals2 = pd.DataFrame(proposals)


# Assume df_responses is the DataFrame containing responses from the GUI
df_responses = app.df_responses.T

# Extract the first row of the DataFrame (assuming one user's responses)
user_responses = df_responses[10:].iloc[:, 0].tolist()

# Insert the user_responses as a new column in df1
df_proposals2['vote'] = user_responses

# Display the updated DataFrame
df_proposals2

# Display the DataFrame for proposals
(df_proposals)=df_proposals2
df_proposals
# Out:
#                                             proposal vote
# 0  Enhance community engagement through monthly t...    1
# 1  Implement a decentralized grants program to fu...    1
# 2  Integrate NFTs to enhance DAO membership and g...    1
# 3  Collaborate with external projects for cross-p...    1
# 4  Implement policies for diverse representation ...    1
# 5  Introduce governance badges or NFTs as recogni...    0
# 6  Create educational initiatives to promote incl...    0
# 7  Implement a clear and accessible dispute resol...    0
# 8  Facilitate open and constructive dialogue betw...    0
# 9  Establish mentorship programs to support under...    0

# %%
# Concatenate the two DataFrames along the columns axis
df_final = pd.concat([df_proposals, vader_df.reset_index(drop=True)], axis=1)

# Display the final DataFrame
(df_final)
# Out:
#                                             proposal vote  \
# 0  Enhance community engagement through monthly t...    1
# 1  Implement a decentralized grants program to fu...    1
# 2  Integrate NFTs to enhance DAO membership and g...    1
# 3  Collaborate with external projects for cross-p...    1
# 4  Implement policies for diverse representation ...    1
# 5  Introduce governance badges or NFTs as recogni...    0
# 6  Create educational initiatives to promote incl...    0
# 7  Implement a clear and accessible dispute resol...    0
# 8  Facilitate open and constructive dialogue betw...    0
# 9  Establish mentorship programs to support under...    0
#
#                                  questions_sentiment  \
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'comp...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'comp...
# ...

# %%
# Assuming 'result_df' is your DataFrame
column_types2 = df_final.dtypes

# Display the schema
print(column_types2)
# Out:
# proposal               object
# vote                   object
# questions_sentiment    object
# User_1_sentiment       object
# dtype: object

# %%
print(df_final)
# Out:
#                                             proposal vote  \
# 0  Enhance community engagement through monthly t...    1
# 1  Implement a decentralized grants program to fu...    1
# 2  Integrate NFTs to enhance DAO membership and g...    1
# 3  Collaborate with external projects for cross-p...    1
# 4  Implement policies for diverse representation ...    1
# 5  Introduce governance badges or NFTs as recogni...    0
# 6  Create educational initiatives to promote incl...    0
# 7  Implement a clear and accessible dispute resol...    0
# 8  Facilitate open and constructive dialogue betw...    0
# 9  Establish mentorship programs to support under...    0
#
#                                  questions_sentiment  \
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'comp...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'comp...
# ...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ameiy\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from nltk.sentiment import SentimentIntensityAnalyzer

# Function to extract sentiment features from the 'questions_sentiment' and 'User_1_sentiment' columns
def extract_sentiment_features(sentiment_dict):
    return list(sentiment_dict.values())

# Apply the function to create sentiment features columns
df_final[['questions_neg', 'questions_neu', 'questions_pos', 'questions_compound']] = pd.DataFrame(
    df_final['questions_sentiment'].apply(extract_sentiment_features).tolist(), index=df_final.index)

df_final[['User_1_neg', 'User_1_neu', 'User_1_pos', 'User_1_compound']] = pd.DataFrame(
    df_final['User_1_sentiment'].apply(extract_sentiment_features).tolist(), index=df_final.index)

# Select features and target variable
features = [
    'questions_neg', 'questions_neu', 'questions_pos', 'questions_compound',
    'User_1_neg', 'User_1_neu', 'User_1_pos', 'User_1_compound'
]
target = 'vote'

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_final[features], df_final[target], test_size=0.2, random_state=42)

# Initialize the Random Forest classifier with the best hyperparameters
best_rf_model = RandomForestClassifier(
    max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50, random_state=42
)

# Train the model
best_rf_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = best_rf_model.predict(X_test)

# Evaluate the model accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Model Accuracy: {accuracy:.2%}')

# Display feature importances
feature_importances = best_rf_model.feature_importances_
for feature, importance in zip(features, feature_importances):
    print(f'{feature}: {importance}')

# Sentiment analysis for a new proposal
new_proposal_text = "do you want to be part of this dao"
analyzer = SentimentIntensityAnalyzer()
new_proposal_sentiment = get_sentiment_scores(new_proposal_text)

# Extract sentiment features for the new proposal
new_proposal_features = extract_sentiment_features(new_proposal_sentiment) + \
                        extract_sentiment_features(new_proposal_sentiment)

# Reshape the features into a 2D array (needed for prediction)
new_proposal_features = np.array(new_proposal_features).reshape(1, -1)

# Use the trained model for prediction
predicted_vote = best_rf_model.predict(new_proposal_features)

# Display the predicted vote for the new proposal
print(f'Predicted Vote for the New Proposal: {predicted_vote[0]}')
# Out:
# Model Accuracy: 100.00%
# questions_neg: 0.0
# questions_neu: 0.23255813953488372
# questions_pos: 0.4883720930232558
# questions_compound: 0.27906976744186046
# User_1_neg: 0.0
# User_1_neu: 0.0
# User_1_pos: 0.0
# User_1_compound: 0.0
# Predicted Vote for the New Proposal: 0
# c:\Users\ameiy\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
output_file_path = 'predicted_vote.txt'
# Write the predicted vote to a text file
with open(output_file_path, 'w') as file:
    file.write(str(predicted_vote[0]))
